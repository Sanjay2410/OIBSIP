# %% [markdown]
# <a href="https://colab.research.google.com/github/Sanjay2410/OIBSIP/blob/main/IRIS_FLOWER_CLASSIFICATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# *  So, At first the main aim is to classify the iris flowers among three species which are setosa, versicolor and virginica, which differs according to their measurements.
# *   The iris dataset contains 3 classes of 50 instances each, where each class refers to a type of iris plant.
# *   Our main task is to train a Machine Learning Model that can learn from the measurements of the iris species and classify them.

# %%
#IMPORTING ALL THE NECESSARY LIBRARIES FOR OUR PROJECT
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#LOADING THE DATA SET INTO THE ENVIRONMENT
columns = ['Sepal length', 'Sepal width', 'Petal length', 'Petal width', 'Class_labels']

df = pd.read_csv('iris.data', names = columns)
sns.set()

# %%
df.head(50)
# Out:
#     Sepal length  Sepal width  Petal length  Petal width Class_labels
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %% [markdown]
# **VISUALIZATION OF IRIS DATASET**

# %%
df.describe()
# Out:
#        Sepal length  Sepal width  Petal length  Petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.pairplot(df, hue = 'Class_labels')

# %%
#SEPARATING INPUT COLUMNS AND OUTPUT COLUMN
data = df.values
X = data[:, 0:4]
Y = data[:, 4]

# %%
#SPLITTING THE DATA INTO TRAINING AND TESTING
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size = 0.2)
print(X_test)
# Out:
# [[6.7 3.0 5.0 1.7]
#  [7.4 2.8 6.1 1.9]
#  [6.7 3.1 4.4 1.4]
#  [6.3 2.5 5.0 1.9]
#  [6.5 3.0 5.8 2.2]
#  [5.3 3.7 1.5 0.2]
#  [5.1 3.8 1.9 0.4]
#  [6.7 3.0 5.2 2.3]
#  [6.8 2.8 4.8 1.4]
#  [6.7 2.5 5.8 1.8]
#  [7.6 3.0 6.6 2.1]
#  [4.6 3.1 1.5 0.2]
#  [5.7 2.9 4.2 1.3]
#  [5.1 2.5 3.0 1.1]
#  [6.3 2.8 5.1 1.5]
#  [6.4 3.1 5.5 1.8]
#  [6.3 3.3 4.7 1.6]
#  [6.6 2.9 4.6 1.3]
#  [6.2 2.2 4.5 1.5]
#  [5.0 3.2 1.2 0.2]
#  [5.4 3.7 1.5 0.2]
#  [5.0 3.4 1.6 0.4]
#  [5.9 3.0 4.2 1.5]
#  [6.5 3.2 5.1 2.0]
#  [7.2 3.0 5.8 1.6]
#  [5.5 2.4 3.7 1.0]
#  [5.4 3.9 1.3 0.4]
#  [6.9 3.1 5.4 2.1]
#  [6.8 3.0 5.5 2.1]
#  [4.9 3.0 1.4 0.2]]

# %% [markdown]
# **SUPPORT VECTOR MACHINE - MODEL 1**

# %%
#SUPPORT VECTOR MACHINE ALGORITHM
from sklearn.svm import SVC
model_svc = SVC()
model_svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
pred1 = model_svc.predict(X_test)

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred1) * 100)
# Out:
# 96.66666666666667

# %% [markdown]
# **LOGISTIC REGRESSION - MODEL 2**

# %%
from sklearn.linear_model import LogisticRegression
model_LR = LogisticRegression()
model_LR.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
pred2 = model_LR.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,pred2)*100)
# Out:
# 96.66666666666667

# %% [markdown]
# **DECISION TREE CLASSIFIER - MODEL 3**

# %%
from sklearn.tree import DecisionTreeClassifier
model_DTC = DecisionTreeClassifier()
model_DTC.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred3 = model_DTC.predict(X_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred3) * 100)
# Out:
# 93.33333333333333

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, pred2))
# Out:
#                  precision    recall  f1-score   support
#
#     Iris-setosa       1.00      1.00      1.00         8
# Iris-versicolor       1.00      0.90      0.95        10
#  Iris-virginica       0.92      1.00      0.96        12
#
#        accuracy                           0.97        30
#       macro avg       0.97      0.97      0.97        30
#    weighted avg       0.97      0.97      0.97        30

# %%
X_new = np.array([[3,2,1,0.2],[4.9,2.2,3.8,1.1],[5.3,2.5,4.6,1.9]])
pred = model_svc.predict(X_new)
print("Prediction of Species: {}",format(pred))
# Out:
# Prediction of Species: {} ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
